# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Science in Practice/Data and input tool/Processed Data/media_reports_processed.csv')

# %%
df['Event-Type Precision'].nunique()
# Out:
# 4

# %%
# Number of event type precision
df['Event Type'].value_counts().plot.bar()
plt.set_size_inches(18.5, 10.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f7e323300a99> in <module>
#       1 # Number of event type precision
#       2 df['Event Type'].value_counts().plot.bar()
# ----> 3 plt.set_size_inches(18.5, 10.5)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_size_inches'

# %% [markdown]
# # Plot per country

# %%
df_Libya = df
df_Tunisia = df
df_Italy = df
df_Niger = df
df_Malta = df
df_Spain = df
df_Ghana = df
df_Morocco = df

df_Libya = df_Libya[df.Country == 'Libya']
df_Tunisia = df_Tunisia[df.Country == 'Tunisia']
df_Italy = df_Italy[df.Country == 'Italy']
df_Niger = df_Niger[df.Country == 'Niger']
df_Malta = df_Malta[df.Country == 'Malta']
df_Spain = df_Spain[df.Country == 'Spain']
df_Ghana = df_Ghana[df.Country == 'Ghana']
df_Morocco = df_Morocco[df.Country == 'Morocco']

# %%
# Number of event type precision Libya
df_Libya['Event-Type Precision'].value_counts().plot.barh()

# %%
# Number of event type precision Tunisia
df_Tunisia['Event-Type Precision'].value_counts().plot.barh()

# %%
# Number of event type precision Italy
df_Italy['Event-Type Precision'].value_counts().plot.barh()

# %%
# Number of event type precision Niger
df_Niger['Event-Type Precision'].value_counts().plot.barh()

# %%
# Number of event type precision Malta
df_Malta['Event-Type Precision'].value_counts().plot.barh()

# %%
# Number of event type precision Spain
df_Spain['Event-Type Precision'].value_counts().plot.barh()

# %%
# Number of event type precision Ghana
df_Ghana['Event-Type Precision'].value_counts().plot.bar()

# %%
# Number of event type precision Morocco
# Error caused by empty dataframe (no events for morocco)
df_Morocco['Event-Type Precision'].value_counts().plot.bar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-11131fe6b347> in <module>
#       1 # Number of event type precision Morocco
#       2 # Error caused by empty dataframe (no events for morocco)
# ----> 3 df_Morocco['Event-Type Precision'].value_counts().plot.bar()
#
# NameError: name 'df_Morocco' is not defined
