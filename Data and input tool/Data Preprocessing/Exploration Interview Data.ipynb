# %%
import pandas as pd 
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load via drive
df = pd.read_csv('/content/drive/MyDrive/Data Science in Practice/Data and input tool/Raw Data/interviews 31 Janv.csv', sep=',', encoding='ISO-8859-1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 35 columns):
#  #   Column                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                          --------------  -----
#  0   Number of interview                                                                                                                             124 non-null    float64
#  1   Number of interviewee                                                                                                                           124 non-null    float64
#  2   How many people interviewe                                                                                                                      124 non-null    float64
# ...

# %%
df['interviewee (migrant/source person)'].value_counts()
# Out:
# migrant          76
# source person    48
# Name: interviewee (migrant/source person), dtype: int64

# %%
df['precision migrant (migrants, asylum seeker, refugee)'].value_counts()
# Out:
# migrant          43
# asylum seeker    18
# refugee          12
# students          1
# migrant           1
# student           1
# Name: precision migrant (migrants, asylum seeker, refugee), dtype: int64

# %%
df['precision source person (Autorities, NGO, expert, other)'].value_counts()
# Out:
# other         23
# NGO           15
# expert         5
# Autorities     3
# autorities     1
# ONG            1
# Name: precision source person (Autorities, NGO, expert, other), dtype: int64
